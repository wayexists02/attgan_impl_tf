# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "2,3"

import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt

from env import *
from DataLoader import DataLoader
from AttGan import AttGan

# %%
# construct test image
test_image = cv2.imread(TEST_IMAGE)
test_image = cv2.resize(test_image, dsize=(HEIGHT, WIDTH))
test_image = (np.float32(test_image) - 128) / 128
test_image_rgb = np.ubyte((test_image + 1) * 128)
test_image_rgb = cv2.cvtColor(test_image_rgb, cv2.COLOR_BGR2RGB)

print("Initial Image:")
plt.imshow(test_image_rgb)
plt.show()

# construct data loader
dloader = DataLoader(BATCH_SIZE)
dloader.build()

# construct model
model = AttGan(eta=ETA, num_att=dloader.num_att)
model.build()


test_att = np.array([-1, 1, 1])

# tensorboard settings
# tf.summary.FileWriter("./logdir/", graph=model.graph)

# train
for e in range(EPOCHS):
    
    # loss for generator and discriminator
    train_loss_g = 0.0
    train_loss_d = 0.0
    
    # batch train step
    for X_src, X_att_a, X_att_b in dloader.next_batch():
        loss_g, loss_d = model.step(X_src, X_att_a, X_att_b)
        train_loss_g += loss_g
        train_loss_d += loss_d
        
    # compute loss
    train_loss_g /= len(dloader)
    train_loss_d /= len(dloader)
    
    print(f"Epochs {e+1}/{EPOCHS}")
    print(f"Train generator loss: {train_loss_g:.8f}")
    print(f"Train discriminator loss: {train_loss_d:.8f}")
    
    # test attgan
    test_result = model.convert(test_image.reshape(-1, *test_image.shape), test_att.reshape(-1, *test_att.shape))
    test_result = test_result.squeeze()
    
    test_result = np.ubyte((test_result + 1) * 128)
    test_result = cv2.cvtColor(test_result, cv2.COLOR_BGR2RGB)
    plt.imshow(test_result)
    plt.show()
    
model.save("./ckpts/attgan")
# Out:
# 255 0
# 0.9921875 -1.0
# 255 0 (96, 96, 3)
# Selected attributes:
# ['Bald' 'Eyeglasses' 'Male']
# Number of images: 202599
# Number of attributes: 3
# Number of batches: 1583
# Initial Image:
# Building Attgan...
# Building generator 0...
# Generator 0 was built.
# Building discriminator 0...
# Discriminator 0 was built.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~/miniconda3/envs/tf1env/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2408       with c_api_util.tf_buffer() as buf:
# -> 2409         c_api.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2410         data = c_api.TF_GetBuffer(buf)
#
# InvalidArgumentError: Operation 'attgan_0/d_1/add_4' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/miniconda3/envs/tf1env/lib/python3.7/site-packages/tensorflow/python/ops/gradients_impl.py in _MaybeCompile(scope, op, func, grad_fn)
#     414     try:
# --> 415       xla_compile = op.get_attr("_XlaCompile")
#     416       xla_separate_compiled_gradients = op.get_attr(
#
# ~/miniconda3/envs/tf1env/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2412       # Convert to ValueError for backwards compatibility.
# -> 2413       raise ValueError(str(e))
#    2414     x = attr_value_pb2.AttrValue()
#
# ValueError: Operation 'attgan_0/d_1/add_4' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-7ea0bae08074> in <module>
#      20 # construct model
#      21 model = AttGan(eta=ETA, num_att=dloader.num_att)
# ---> 22 model.build()
#      23
#      24
#
# ~/projects/attgan_impl_tf/AttGan.py in build(self)
#     107                         loss_d_list.append(loss_d)
#     108
# --> 109                         g_grad_var_pair = optimizer_g.compute_gradients(loss_g, var_list=self.Gparams)
#     110                         d_grad_var_pair = self._compute_discriminator_gradients(optimizer_d, loss_d, gp)
#     111
#
# ~/miniconda3/envs/tf1env/lib/python3.7/site-packages/tensorflow/python/training/optimizer.py in compute_gradients(self, loss, var_list, gate_gradients, aggregation_method, colocate_gradients_with_ops, grad_loss)
#     510         gate_gradients=(gate_gradients == Optimizer.GATE_OP),
#     511         aggregation_method=aggregation_method,
# --> 512         colocate_gradients_with_ops=colocate_gradients_with_ops)
#     513     if gate_gradients == Optimizer.GATE_GRAPH:
#     514       grads = control_flow_ops.tuple(grads)
#
# ~/miniconda3/envs/tf1env/lib/python3.7/site-packages/tensorflow/python/ops/gradients_impl.py in gradients(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients)
#     662     return _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops,
#     663                             gate_gradients, aggregation_method, stop_gradients,
# --> 664                             unconnected_gradients)
#     665
#     666
#
# ~/miniconda3/envs/tf1env/lib/python3.7/site-packages/tensorflow/python/ops/gradients_impl.py in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients, unconnected_gradients, src_graph)
#     963                 # functions.
#     964                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 965                                          lambda: grad_fn(op, *out_grads))
#     966               else:
#     967                 # For function call ops, we add a 'SymbolicGradient'
#
# ~/miniconda3/envs/tf1env/lib/python3.7/site-packages/tensorflow/python/ops/gradients_impl.py in _MaybeCompile(scope, op, func, grad_fn)
#     418       xla_scope = op.get_attr("_XlaScope").decode()
#     419     except ValueError:
# --> 420       return grad_fn()  # Exit early
#     421
#     422   if not xla_compile:
#
# ~/miniconda3/envs/tf1env/lib/python3.7/site-packages/tensorflow/python/ops/gradients_impl.py in <lambda>()
#     963                 # functions.
#     964                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 965                                          lambda: grad_fn(op, *out_grads))
#     966               else:
#     967                 # For function call ops, we add a 'SymbolicGradient'
#
# ~/miniconda3/envs/tf1env/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py in _AddGrad(op, grad)
#     907   sy = array_ops.shape(y)
#     908   rx, ry = gen_array_ops.broadcast_gradient_args(sx, sy)
# --> 909   return (array_ops.reshape(math_ops.reduce_sum(grad, rx), sx),
#     910           array_ops.reshape(math_ops.reduce_sum(grad, ry), sy))
#     911
#
# ~/miniconda3/envs/tf1env/lib/python3.7/site-packages/tensorflow/python/ops/gen_array_ops.py in reshape(tensor, shape, name)
#    7177   try:
#    7178     _, _, _op = _op_def_lib._apply_op_helper(
# -> 7179         "Reshape", tensor=tensor, shape=shape, name=name)
#    7180   except (TypeError, ValueError):
#    7181     result = _dispatch.dispatch(
#
# ~/miniconda3/envs/tf1env/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     786         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     787                          input_types=input_types, attrs=attr_protos,
# --> 788                          op_def=op_def)
#     789       return output_structure, op_def.is_stateful, op
#     790
#
# ~/miniconda3/envs/tf1env/lib/python3.7/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     478       if is_in_graph_mode.IS_IN_GRAPH_MODE() and _PRINT_DEPRECATION_WARNINGS:
#     479         invalid_args = []
# --> 480         named_args = tf_inspect.getcallargs(func, *args, **kwargs)
#     481         for arg_name, spec in iter(deprecated_positions.items()):
#     482           if (spec.position < len(args) and
#
# ~/miniconda3/envs/tf1env/lib/python3.7/site-packages/tensorflow/python/util/tf_inspect.py in getcallargs(func, *positional, **named)
#     260   argspec will be used.
#     261   """
# --> 262   argspec = getfullargspec(func)
#     263   call_args = named.copy()
#     264   this = getattr(func, 'im_self', None) or getattr(func, '__self__', None)
#
# ~/miniconda3/envs/tf1env/lib/python3.7/site-packages/tensorflow/python/util/tf_inspect.py in getfullargspec(obj)
#     241   return next((d.decorator_argspec
#     242                for d in decorators
# --> 243                if d.decorator_argspec is not None), _getfullargspec(target))
#     244
#     245
#
# ~/miniconda3/envs/tf1env/lib/python3.7/inspect.py in getfullargspec(func)
#    1124                                        follow_wrapper_chains=False,
#    1125                                        skip_bound_arg=False,
# -> 1126                                        sigcls=Signature)
#    1127     except Exception as ex:
#    1128         # Most of the times 'signature' will raise ValueError.
#
# ~/miniconda3/envs/tf1env/lib/python3.7/inspect.py in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, sigcls)
#    2282         # If it's a pure Python function, or an object that is duck type
#    2283         # of a Python function (Cython functions, for instance), then:
# -> 2284         return _signature_from_function(sigcls, obj)
#    2285
#    2286     if _signature_is_builtin(obj):
#
# ~/miniconda3/envs/tf1env/lib/python3.7/inspect.py in _signature_from_function(cls, func)
#    2159         parameters.append(Parameter(name, annotation=annotation,
#    2160                                     kind=_POSITIONAL_OR_KEYWORD,
# -> 2161                                     default=defaults[offset]))
#    2162
#    2163     # *args
#
# ~/miniconda3/envs/tf1env/lib/python3.7/inspect.py in __init__(self, name, kind, default, annotation)
#    2465     empty = _empty
#    2466
# -> 2467     def __init__(self, name, kind, *, default=_empty, annotation=_empty):
#    2468         try:
#    2469             self._kind = _ParameterKind(kind)
#
# KeyboardInterrupt:

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("data_sample_/img_align_celeba/000052.jpg")
img = cv2.resize(img, dsize=(96, 96)).astype(np.float32)

img = (img - 128) / 128

img_src = cv2.cvtColor((img + 1)/2, cv2.COLOR_BGR2RGB)
plt.imshow(img_src)

# %%
img_converted = model.convert(img.reshape(1, *img.shape), np.ones((1, 1)))

# %%
img_converted = cv2.cvtColor(img_converted.squeeze(), cv2.COLOR_BGR2RGB)
plt.imshow((img_converted*127 + 128)/255)
